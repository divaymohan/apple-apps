# %%
import pandas as pd

# %%
df = pd.read_csv("AppleStore.csv")

# %%
df.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
df.currency.unique()
# Out:
# array(['USD'], dtype=object)

# %%
feature_set = ['size_bytes', 'price',
       'rating_count_tot', 'rating_count_ver', 'user_rating',
       'user_rating_ver', 
       'sup_devices.num']

# %%
apple_featureset=df[feature_set]

# %%
apple_featureset.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0   100788224   3.99             21292                26          4.0
# 1   158578688   0.00            161065                26          4.0
# 2   100524032   0.00            188583              2822          3.5
# 3   128512000   0.00            262241               649          4.0
# 4    92774400   0.00            985920              5320          4.5
#
#    user_rating_ver  sup_devices.num
# 0              4.5               38
# 1              3.5               37
# 2              4.5               37
# 3              4.5               37
# 4              5.0               37

# %%
type(apple_featureset.rating_count_tot[0])
# Out:
# numpy.int64

# %%
apple_featureset.describe()
# Out:
#          size_bytes        price  rating_count_tot  rating_count_ver  \
# count  7.197000e+03  7197.000000      7.197000e+03       7197.000000
# mean   1.991345e+08     1.726218      1.289291e+04        460.373906
# std    3.592069e+08     5.833006      7.573941e+04       3920.455183
# min    5.898240e+05     0.000000      0.000000e+00          0.000000
# 25%    4.692275e+07     0.000000      2.800000e+01          1.000000
# 50%    9.715302e+07     0.000000      3.000000e+02         23.000000
# 75%    1.819249e+08     1.990000      2.793000e+03        140.000000
# max    4.025970e+09   299.990000      2.974676e+06     177050.000000
#
#        user_rating  user_rating_ver  sup_devices.num
# count  7197.000000      7197.000000      7197.000000
# mean      3.526956         3.253578        37.361817
# std       1.517948         1.809363         3.737715
# min       0.000000         0.000000         9.000000
# 25%       3.500000         2.500000        37.000000
# ...

# %%
y = df.price

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state=1)

# %%
model.fit(apple_featureset,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
prediction = model.predict(apple_featureset.head())

# %%
prediction
# Out:
# array([3.99, 0.  , 0.  , 0.  , 0.  ])

# %%
df.groupby('prime_genre')['track_name'].nunique()
# Out:
# prime_genre
# Book                  112
# Business               57
# Catalogs               10
# Education             453
# Entertainment         535
# Finance               104
# Food & Drink           63
# Games                3860
# Health & Fitness      180
# Lifestyle             144
# Medical                23
# Music                 138
# Navigation             46
# News                   75
# Photo & Video         349
# Productivity          178
# Reference              64
# Shopping              122
# Social Networking     167
# Sports                114
# Travel                 81
# Utilities             248
# Weather                72
# Name: track_name, dtype: int64

# %%
import matplotlib.pyplot
# %matplotlib inline

# %%
df.groupby('prime_genre')['track_name'].nunique().plot()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
# Unnamed: 0          7197 non-null int64
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# user_rating_ver     7197 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     7197 non-null int64
# lang.num            7197 non-null int64
# vpp_lic             7197 non-null int64
# dtypes: float64(3), int64(9), object(5)
# memory usage: 955.9+ KB

# %%
df.groupby('prime_genre')['user_rating'].mean().plot()

# %%
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %%
apps.head()
# Out:
# prime_genre
# Book             112
# Business          57
# Catalogs          10
# Education        453
# Entertainment    535
# Name: track_name, dtype: int64

# %%
type(apps)
# Out:
# pandas.core.series.Series
